# %% [markdown]
# <a href="https://colab.research.google.com/github/hrico2477/PA-1C-grupo-A/blob/main/batatafrita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome=("Mario") #variável tipo str (string)
idade= 25 #variável número inteiro
altura=1.8 #variável tipo float

# %%
print (altura)
# Out:
# 1.8
