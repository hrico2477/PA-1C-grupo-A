# %% [markdown]
# <a href="https://colab.research.google.com/github/hrico2477/PA-1C-grupo-A/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import altsep
#Calucular #Aréa do retângulo

#Entrada

Comprimento=float(input("Digite o comprimento do retângulo: "))
altura=float(input("Digite a altura do retângulo:  "))

#processamento

Area= Comprimento * altura

#Saida

print ("-------ÁREA DO RETÂNGULO-------")
print("")
print(f"Área total do retâtangulo é igual : {Area}")
print("")
print("------------------------------------")
# Out:
# Digite o comprimento do retângulo: 21
# Digite a altura do retângulo:  21
# -------ÁREA DO RETÂNGULO-------
#
# Área total do retâtangulo é igual : 441.0
#
# ------------------------------------

# %%
#Entrada
print("--------------ENTRADA DA TEMPERATURA-------")
celsius = float(input("Digite a temperatura em graus celsius:  "))

#Processamento
fahrenheit = (celsius * 9/5) + 32

#Saida
print("----------------CONVERSÂo-----------")
print(f"A temperatura em fahrenheit é: {fahrenheit}")
# Out:
# --------------ENTRADA DA TEMPERATurA-------
# Digite a temperatura em graus celsius:  23
# ----------------CONVERSÂo-----------
# A temperatura em fahrenheit é: 73.4

# %%
#Entrada

num1=int(input("Digite um número: "))
num2=int(input("Digite um número: "))

#Processamento

igual= num1 == num2#igual
difernete = num1 != num2#difernete
maior= num1 > num2#maior
menor= num1 < num2#menor
menor igual= num1 <= num2#menor igual
maior igual= num1 >= num2#maior igual
#Saída

print(igual)
print(difernete)
print(maior)
print(menor)
print(menor igual)
print(maior igual)
