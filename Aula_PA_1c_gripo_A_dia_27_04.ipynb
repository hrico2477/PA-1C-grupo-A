# %% [markdown]
# <a href="https://colab.research.google.com/github/hrico2477/PA-1C-grupo-A/blob/main/Aula_PA_1c_gripo_A_dia_27_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Interações e laços de repetição
# Out:
#   File "/tmp/ipykernel_3877/2539375857.py", line 1
#     Hello word ("print")
#           ^
# SyntaxError: invalid syntax

# %%
for i in range (5):
   print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 6) :
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Escrever um programa que imprime de 5 até 0

for i in range (7) :
  print(6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# Escrever um programa que imprime os números pares de 0 a 10

for i in range (11):

  if i % 2 == 0:
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#  imprimi números pares
for i in range (0,11,2) :
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
#  imprimi números impares
for i in range (1,11,2) :
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#  Escrever um programa que o usuario digita um número de 1 a 10 e imprime a tabuada.

A = int(input("Digite o número:  "))

for i in range(1, 11):
  print(f"{A} x {i} = {A * i}")
# Out:
# Digite o número:  9999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999
# 9999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999 x 1 = 9999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999
# 9999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999 x 2 = 19999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999999998
# ...
