# %% [markdown]
# <a href="https://colab.research.google.com/github/hrico2477/PA-1C-grupo-A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Opereadores aritimeticos
#
# Soma +
#
# Subtração -
#
# Mutiplicação *
#
# Divisão/

# %%
# Entrada

Lado=6

# Processamento

Quadrado= Lado*Lado

# Saida

print(f"Total da área do quadrado: {Quadrado}")
# Out:
# Total da área do quadrado: 36

# %% [markdown]
# Escrever um algoritimo que calcula a áreade de uma sala
#
# # Entrada
#
# Ler o comprimento
# Ler a altura
#
# # Processameto
#
# Multiplicar comprimento com altura
#
# # Saida
#
# Mostrar o total de área

# %%
# Entrada
Comprimento=13
Altura= 6
# Procesamento
Sala= Comprimento*Altura
# Saida
print (Sala)
# Out:
# 78

# %% [markdown]
# Escreva um algoritimo e o programa que recebe 04 notas do aluno e calcula a média depois mostra a média

# %%
#Entrada

nota=6
nota2=8
nota3=5
nota4=9

#Procesamento

media= (nota+nota2+nota3+nota4)/4

# Saida
print(f"A media é {media}")
# Out:
# A media é 7.0

# %%
#Entrada
altura= 3
largura=6
#Processamento
Area=(altura+largura)*2

print(f"o dobro da area é {Area}")
# Out:
# o dobro da area é 18
