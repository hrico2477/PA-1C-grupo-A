# %%
idade = int(input("digite sua idade:  "))
if idade <= 17:
    print("Menor de idade")
elif idade <= 59:
    print("Você é adulto")
elif idade >= 60:
    print("Você é idoso")
# Out:
# Você é idoso

# %%
Valor = int(input("Digite o preço do produto: "))
if Valor <= 100: 
    print(f"seu valor é de: {Valor} ")
elif Valor >= 101:
    Resultado = Valor * 0.10
    Valorfinal = Valor - Resultado
    print(f"o valor da compra é {Valorfinal}")
elif Valor >= 500:
    Resultado = Valor * 0.20
    Valorfinal = Valor - Resultado
    print(f"o valor da compra é {Valorfinal}")
# Out:
# o valor da compra é 720.0

# %%
a=int(input("digite seu lado  "))
b=int(input("digite seu segundo lado  "))
c=int(input("digite seu terceiro lado  "))

if a+b>c and a+c>b and b+c>a:
  print("isso é um triagulo")
elif a+b<c or a+c<b and b+c<a:
  print("isso não é um triagulo")

if a==b==c:
  print ("equilátero")
elif a==b or a==c or b==c:
  print("isóceles")
else:
  print("escaleno")
# Out:
# isso é um triagulo
# escaleno

# %%
p = int(input("Digite a energia do personagem: "))

if p == 0:
    print("Morto")
elif p <= 30:
    print("Crítico")
elif p <= 70:
    print("Normal")
elif p <= 100:
    print("Saudável")
# Out:
# Saudável

# %%
A= int(input("Digite a nota:  "))
B= int(input("Digite a nota:  "))
C= int(input("Digite a nota:  "))
D= int(input("Digite a nota:  "))

Valor= A+B+C+D
Media= Valor/4

if Media >= 7: 
    print(f"Sua nota foi {Media} aprovado")
elif Media >= 5: 
    print(f"Sua nota foi {Media} recuperação")
elif Media < 5: 
    print(f"Sua nota foi {Media} reprovado")
# Out:
# Sua nota foi 1.0 reprovado

# %%
Salario =int(input("Digite seu salario:  "))
pontuação= int(input("Digite sua pontuação:  "))

if pontuação < 5 : 
    print(f"{Salario}")
elif pontuação <= 7 :
  Valor= Salario * 0.05
  Valorfinal= Salario + Valor

  print(f"{Valorfinal}")
elif pontuação <= 9 :
  Valor= Salario * 0.10
  Valorfinal= Salario + Valor

  print(f"{Valorfinal}")
elif pontuação = 10 :
  Valor= Salario * 0.15
  Valorfinal= Salario + Valor

  print(f"{Valorfinal}")
# Out:
# 1050.0
